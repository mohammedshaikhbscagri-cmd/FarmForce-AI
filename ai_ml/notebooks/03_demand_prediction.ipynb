# %% [markdown]
# # FarmForce AI — Labor Demand Prediction
#
# Predict labor demand using historical data and weather forecasts.

# %% [markdown]
# ## 1. Load Demand Predictor

# %%
import sys
sys.path.append('..')
from prediction.demand_predictor import LaborDemandPredictor

predictor = LaborDemandPredictor()
farm = {'current_stage': 'harvesting'}
weather = [{'rainfall': 0, 'temperature': 30}] * 7
predictions = predictor.predict(farm, weather)
print(predictions)

# %% [markdown]
# ## 2. Train Prophet Model

# %%
# TODO: Train Facebook Prophet on historical labor demand data
print('Prophet model training TODO')
