# %% [markdown]
# # FarmForce AI — Matching Model Development
#
# Develop and evaluate the AI worker-job matching model.

# %% [markdown]
# ## 1. Feature Engineering

# %%
import sys
sys.path.append('..')
from matching.matching_model import MatchingEngine
from matching.feature_engineering import compute_distance_features, compute_skill_features

engine = MatchingEngine()
print('MatchingEngine loaded successfully')

# %% [markdown]
# ## 2. Model Evaluation

# %%
# TODO: Load test dataset and evaluate matching quality
print('Model evaluation TODO')
